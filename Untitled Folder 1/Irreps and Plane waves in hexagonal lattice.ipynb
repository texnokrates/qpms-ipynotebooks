# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np
import math
ň = None
s3 = math.sqrt(3)
pp = np.pi/2 #pípůl

# %%
def kpointplanewaves(phases = (0,0,0,0,0,0), facs = (1,1,1,1,1,1), Kmultiplier=1, ascale=20, wscale=20, sscale=100, gphase=0, noplot=False):
    facs = np.array(facs)
    phases = np.array(phases,dtype=float)
    phases += gphase
    hsl = 1 # hexagon side length
    n1 = 5
    n2 = 5
    b1 = np.array((0,hsl*s3))
    b2 = np.array((hsl*3/2,hsl*s3/2))
    Ashift = np.array((-hsl,0))
    Bshift = np.array((hsl,0))

    Asites = np.arange(-n1,n1)[:,ň,ň] * b1[ň,ň,:] + np.arange(-n2,n2)[ň,:,ň] * b2[ň,ň,:] + Ashift
    Asites = np.reshape(Asites,(np.prod(Asites.shape[:-1]), Asites.shape[-1]))
    Bsites = Asites - Ashift + Bshift

    Klen = 4*np.pi/3/s3/hsl*Kmultiplier
    wi = np.arange(6)
    K = Klen * np.stack((np.cos(np.pi*(1/6+wi/3)),np.sin(np.pi*(1/6+wi/3))), axis=-1)
    up = np.stack((np.cos(np.pi*(4/6+wi/3)),np.sin(np.pi*(4/6+wi/3))), axis=-1)
    if not noplot:
        f, ax = plt.subplots(1)
    else:
        f = None
        ax = None
    
    if not noplot:
        for i in range(3): # osy
            ax.plot(*np.transpose([-4*K[i],4*K[i]]),ls='-',c='k')
    iticks = np.arange(-32*n1,32*n1)[ň,:,ň]*K[:,ň,:]  / Klen * s3/32
    iphases = np.sum(iticks * K[:,ň,:]-phases[:,ň,ň], axis=-1 )
    iwaves = np.cos(iphases)[:, :, ň] * up[:, ň, :] * facs[:, ň, ň]
    phaseA = np.tensordot(K, Asites, axes=(-1,-1))-phases[:,ň]
    phaseB = np.tensordot(K, Bsites, axes=(-1,-1))-phases[:,ň]
    Awave = np.sum(np.cos(phaseA)[:, :, ň] * up[:, ň, :] * facs[:, ň, ň], axis=0)
    AwaveH = np.sum(np.sin(phaseA)[:, :] * facs[:, ň], axis=0)
    Awave*=(abs(Awave)>1e-13)
    Bwave = np.sum(np.cos(phaseB)[:, :, ň] * up[:, ň, :] * facs[:, ň, ň], axis=0)
    BwaveH = np.sum(np.sin(phaseB)[:, :] * facs[:, ň], axis=0)
    Bwave*=(abs(Bwave)>1e-13)
    scale_units = 'width'
    
    if not noplot:
        for i in range(6):
            ax.quiver(iticks[i,:,0], iticks[i,:,1],
                       iwaves[i,:,0],
                       iwaves[i,:,1],
                     lw=0.2, color= 'green' if (i < 3) else 'red', headwidth=0, scale_units=scale_units, scale = wscale)

        sites = np.concatenate((Asites, Bsites))
        waveH = np.concatenate((AwaveH, BwaveH))
        #print (abs(waveH)*sscale)
        ax.scatter(Asites[:,0], Asites[:,1], marker='+', c='orange')
        ax.scatter(Bsites[:,0], Bsites[:,1], marker='+', c='magenta')
        ax.scatter(sites[:,0], sites[:,1], marker='o', s=abs(waveH)*sscale,
                   c=np.where(waveH>0,'pink','lightblue') )
        ax.quiver(Asites[:,0],Asites[:,1],Awave[:,0],Awave[:,1],headwidth=0, scale_units = scale_units, scale=ascale)
        ax.quiver(Bsites[:,0],Bsites[:,1],Bwave[:,0],Bwave[:,1],headwidth=0, scale_units = scale_units, scale=ascale)
        #plt.plot(*np.transpose(upiticks),ls='',marker='o')
        #plt.plot(*np.transpose(rupiticks),ls='',marker='o')
        #plt.plot(*np.transpose(lupiticks),ls='',marker='o')
        ax.set_xlim(-4.5,4.5)
        ax.set_ylim(-3,3)
    return (Awave,Bwave,AwaveH, BwaveH, Asites, Bsites, iticks, iwaves, f,  ax)

def justplot(Awave, Bwave, AwaveH, BwaveH, Asites, Bsites, iticks, iwaves, ascale=20, wscale=20, sscale=100):
    hsl=1
    Klen = 4*np.pi/3/s3/hsl#*Kmultiplier
    wi = np.arange(6)
    K = Klen * np.stack((np.cos(np.pi*(1/6+wi/3)),np.sin(np.pi*(1/6+wi/3))), axis=-1)
    up = np.stack((np.cos(np.pi*(4/6+wi/3)),np.sin(np.pi*(4/6+wi/3))), axis=-1)

    
    sites = np.concatenate((Asites, Bsites))
    waveH = np.concatenate((AwaveH, BwaveH))

    f, ax = plt.subplots(1)
    for i in range(3): # osy
        ax.plot(*np.transpose([-4*K[i],4*K[i]]),ls='-',c='k')

    scale_units = 'width'
    for i in range(6):
        ax.quiver(iticks[i,:,0], iticks[i,:,1],
                   iwaves[i,:,0],
                   iwaves[i,:,1],
                 lw=0.2, color= 'green' if (i < 3) else 'red', headwidth=0, scale_units=scale_units, scale = wscale)
    sites = np.concatenate((Asites, Bsites))
    waveH = np.concatenate((AwaveH, BwaveH))
    ax.scatter(Asites[:,0], Asites[:,1], marker='+', c='orange')
    ax.scatter(Bsites[:,0], Bsites[:,1], marker='+', c='magenta')
    ax.scatter(sites[:,0], sites[:,1], marker='o', s=abs(waveH)*sscale,
               c=np.where(waveH>0,'pink','lightblue') )
    ax.quiver(Asites[:,0],Asites[:,1],Awave[:,0],Awave[:,1],headwidth=0, scale_units = scale_units, scale=ascale)
    ax.quiver(Bsites[:,0],Bsites[:,1],Bwave[:,0],Bwave[:,1],headwidth=0, scale_units = scale_units, scale=ascale)
    ax.set_xlim(-4.5,4.5)
    ax.set_ylim(-3,3)
    return (f, ax)

# %%
# Fig 11.11 (b)
kpointplanewaves(phases=(pp,pp,pp,pp,pp,pp), 
                               facs=(1,1,1,1,1,1,), wscale=20);
# Out:
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)

# %%
# Fig 11.11 (a)
kpointplanewaves(phases=(pp,pp,pp,pp,pp,pp),
                 facs=(.5,-1,.5,.5,-1,.5,), wscale=15);
# Out:
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)

# %%
# Fig 11.11 (d)
kpointplanewaves(phases=(pp,pp,pp,pp,pp,pp),
                 facs=(1,0,-1,1,0,-1,), wscale=15);
# Out:
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)

# %%
# Fig 11.11 (a)+(d)
#kpointplanewaves(pru=np.pi/2,pu=np.pi/2,plu=np.pi/2,rufac=2,ufac=-2,lufac=0);
kpointplanewaves(phases=(pp,pp,pp,pp,pp,pp),
                 facs=(1,-1,0,1,-1,0,), wscale=15, ascale=25);
# Out:
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)

# %%
# Fig 11.11 (f)
kpointplanewaves(phases=(pp,pp,pp,pp,pp,pp), 
                               facs=(1,-1,1,1,-1,1,), wscale=20);
# Out:
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)

# %%
Awave1,Bwave1,AwaveH1, BwaveH1, Asites, Bsites, f,  ax = kpointplanewaves(gphase=pp,
                               facs=(1,0,-1,1,0,-1,), wscale=20, noplot=True);
Awave2,Bwave2,AwaveH2, BwaveH2, Asites, Bsites, f,  ax = kpointplanewaves(gphase=0,
                               facs=(.5,-1,.5,.5,-1,.5,), wscale=20, noplot=True);
Awave = Awave1+Awave2
Bwave = Bwave1+Bwave2
AwaveH = AwaveH1+AwaveH2
BwaveH = BwaveH1+BwaveH2
justplot(Awave, Bwave, AwaveH, BwaveH, Asites, Bsites)
# Out:
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-50-6f04bbea73be> in <module>()
#       1 Awave1,Bwave1,AwaveH1, BwaveH1, Asites, Bsites, f,  ax = kpointplanewaves(gphase=pp,
# ----> 2                                facs=(1,0,-1,1,0,-1,), wscale=20, noplot=True);
#       3 Awave2,Bwave2,AwaveH2, BwaveH2, Asites, Bsites, f,  ax = kpointplanewaves(gphase=0,
#       4                                facs=(.5,-1,.5,.5,-1,.5,), wscale=20, noplot=True);
#       5 Awave = Awave1+Awave2
#
# ValueError: too many values to unpack (expected 8)

# %%
kpointplanewaves(gphase=1,
                               facs=(1j,0,-1j,1j,0,-1j,), wscale=20);
# Out:
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)

# %%
# Fig 11.11 (b)
kpointplanewaves(phases=(pp,pp,pp,pp,pp,pp), 
                               facs=(.5,.5,.5,.5,.5,.5,), Kmultiplier=2,
                 wscale=10);
# Out:
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)

# %%
# Fig 11.11 (a)
kpointplanewaves(phases=(pp,pp,pp,pp,pp,pp),
                 facs=(.5,-1,.5,.5,-1,.5,),Kmultiplier=2,
                 wscale=15);
# Out:
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)

# %%
# Fig 11.11 (d)
kpointplanewaves(phases=(pp,pp,pp,pp,pp,pp),
                 facs=(1,0,-1,1,0,-1,), Kmultiplier=2,
                 wscale=15, ascale=25);
# Out:
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)

# %%
# Fig 11.11 (d)
kpointplanewaves(phases=(pp,pp,pp,pp,pp,pp),
                 facs=(1,0,-1,1,0,-1,), Kmultiplier=4,
                 wscale=15, ascale=25);
# Out:
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)

# %%
# Fig 11.11 (b)
gphase = np.linspace(0,2*np.pi,80)
for index, delay in enumerate(gphase):
    _, _, f, _ = kpointplanewaves(phases = (delay,delay,delay,delay,delay,delay,));
    plt.savefig('/tmp/b_frame%03i.png'%index)
    plt.close(f)

# %%
# Fig 11.11 (a)
gphase = np.linspace(0,2*np.pi,80)
for index, delay in enumerate(gphase):
    _, _, f, _ = kpointplanewaves(phases = (delay,delay,delay,delay,delay,delay,), facs=(.5,-1,.5,.5,-1,.5,));
    plt.savefig('/tmp/a_frame%03i.png'%index)
    plt.close(f)

# %%
# Fig 11.11 (d)
gphase = np.linspace(0,2*np.pi,80)
for index, delay in enumerate(gphase):
    _, _, f, _ = kpointplanewaves(phases = (delay,delay,delay,delay,delay,delay,), facs=(1,0,-1,1,0,-1,));
    plt.savefig('/tmp/d_frame%03i.png'%index)
    plt.close(f)

# %%
# Fig 11.11 (f)
gphase = np.linspace(0,2*np.pi,80)
for index, delay in enumerate(gphase):
    _, _, f, _ = kpointplanewaves(phases = (delay,delay,delay,delay,delay,delay,), facs=(1,-1,1,1,-1,1,),
                                 ascale=25);
    plt.savefig('/tmp/f_frame%03i.png'%index)
    plt.close(f)

# %%
#pokusy
gphase = np.linspace(0,2*np.pi,80)
for index, delay in enumerate(gphase):
    _, _, f, _ = kpointplanewaves(phases = (delay,delay,delay,delay,delay,delay,), facs=(.5,-1,.5,0,0,0,));
    plt.savefig('/tmp/x_frame%03i.png'%index)
    plt.close(f)

# %%
#pokusy
gphase = np.linspace(0,2*np.pi,80)
for index, delay in enumerate(gphase):
    _, _, f, _ = kpointplanewaves(gphase=delay,
                               facs=(1+1j,0,-1-1j,1+1j,0,-1-1j,));
    plt.savefig('/tmp/y_frame%03i.png'%index)
    plt.close(f)

# %%
#pokusy
gphase = np.linspace(0,2*np.pi,80)
for index, delay in enumerate(gphase):
    _, _, f, _ = kpointplanewaves(gphase=delay,
                               facs=(.5j,.5j,.5j,.5j,.5j,.5j,));
    plt.savefig('/tmp/z_frame%03i.png'%index)
    plt.close(f)

# %%
#pokusy
gphase = np.linspace(0,2*np.pi,80)
for index, delay in enumerate(gphase):
    Awave1,Bwave1,AwaveH1, BwaveH1, Asites, Bsites, iticks, iwaves1, f,  ax = kpointplanewaves(gphase=pp+delay,
                               facs=(1,0,-1,1,0,-1,), wscale=20, noplot=True);
    Awave2,Bwave2,AwaveH2, BwaveH2, Asites, Bsites, iticks, iwaves2, f,  ax = kpointplanewaves(gphase=0+delay,
                               facs=(.5,-1,.5,.5,-1,.5,), wscale=20, noplot=True);
    Awave = Awave1+Awave2
    Bwave = Bwave1+Bwave2
    AwaveH = AwaveH1+AwaveH2
    BwaveH = BwaveH1+BwaveH2
    iwaves = iwaves1+iwaves2
    f,ax=justplot(Awave, Bwave, AwaveH, BwaveH, Asites, Bsites, iticks, iwaves)
    plt.savefig('/tmp/w_frame%03i.png'%index)
    plt.close(f)
# Out:
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)
# (6, 320, 2)
# (6, 320, 2) (6, 320, 2)

# %% [markdown]
# for i in ${t}_frame*.png ; do  convert $i $(basename $i .png).gif ; done ; convert -delay 10 -loop 0 ${t}_frame*.gif ${t}.gif ; rm ${t}_frame*.*
