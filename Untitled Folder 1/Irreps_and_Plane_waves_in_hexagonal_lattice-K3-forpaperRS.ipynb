# %%
# %matplotlib inline
import matplotlib.tri as tri
from matplotlib import pyplot as plt
import matplotlib
import matplotlib.animation
import numpy as np
import math
import os
import base64
ň = None
s2 = math.sqrt(2)
s3 = math.sqrt(3)
s6 = math.sqrt(6)
s7 = math.sqrt(7)
pi = np.pi
e = np.e
pp = np.pi/2 #pípůl
pt = np.pi/3 #pítřeť



from IPython.display import HTML
print(matplotlib.__version__)
print(dict(matplotlib.animation.writers.avail))
# Out:
# 2.1.2
# {'avconv': <class 'matplotlib.animation.AVConvWriter'>, 'imagemagick': <class 'matplotlib.animation.ImageMagickWriter'>, 'imagemagick_file': <class 'matplotlib.animation.ImageMagickFileWriter'>, 'avconv_file': <class 'matplotlib.animation.AVConvFileWriter'>, 'html': <class 'matplotlib.animation.HTMLWriter'>}

# %%
def kpointplanewaves(phases = (0,0,0,0,0,0), facs = (1,1,1,1,1,1), Kmultiplier=1, ascale=40, wscale=25, sscale=100, gphase=0,
                     rot=False, showcontribs=False, noplot=False, transversal=False, KorKprime = 1, magfield=None, pointmagfield=False,
                     magcmap='bwr', plotaxes = True, plotplanewaves = True, showphase=True,
                     Asitecolor = 'magenta',
                     Bsitecolor = 'orange',
                     Aarrowcolor = 'magenta',
                     Barrowcolor = 'orange',
                    ):
    if magfield is None:
        magfield = transversal
    facs = np.array(facs)
    phases = np.array(phases,dtype=float)
    xl = 3 # plot dimensions
    yl = 3
    diaghalf = (xl**2+yl**2)**0.5
    mgdens=30
    hsl = 1 # hexagon side length
    n1 = 5
    n2 = 5
    b1 = np.array((hsl*s3,0)) if rot else np.array((0,hsl*s3))
    b2 = np.array((hsl*s3/2,-hsl*3/2)) if rot else np.array((hsl*3/2,hsl*s3/2))
    Ashift = np.array((0,hsl)) if rot else np.array((-hsl,0)) 
    Bshift = np.array((0,-hsl)) if rot else np.array((hsl,0))
    
    if magfield:
        nn = np.arange(-mgdens*diaghalf*s3/hsl,mgdens*diaghalf*s3/hsl)
        maggrid = (nn[:,ň,ň]*b1[ň,ň,:] + nn[ň,:,ň]*b2[ň,ň,:]) / mgdens
        maggrid = maggrid[(maggrid[:,:,0] >= -xl) * (maggrid[:,:,0] <= xl) * 
                          (maggrid[:,:,1] >= -yl) * (maggrid[:,:,1] <= yl)]
     
        
    Asites = np.arange(-n1,n1)[:,ň,ň] * b1[ň,ň,:] + np.arange(-n2,n2)[ň,:,ň] * b2[ň,ň,:] + Ashift
    Asites = np.reshape(Asites,(np.prod(Asites.shape[:-1]), Asites.shape[-1]))
    Bsites = Asites - Ashift + Bshift

    Klen = 4*np.pi/3/s3/hsl*Kmultiplier
    K3len = s7*Klen
    wi = np.arange(6)
    K3angles = math.atan(1/(3*s3)) * KorKprime * (-1 + 2 * (np.arange(6)%2)) + pt * (1 + np.arange(6))
    up3angles = K3angles + pp * transversal
    #K = Klen * np.stack((np.cos(np.pi*(1/6-rot/2+wi/3)),np.sin(np.pi*(1/6-rot/2+wi/3))), axis=-1)
    K3 = K3len * np.stack((np.cos(K3angles),np.sin(K3angles)),axis=-1)
    #up = np.stack((np.cos(np.pi*(4/6-rot/2+wi/3)),np.sin(np.pi*(4/6-rot/2+wi/3))), axis=-1)
    up3 = np.stack((np.cos(up3angles),np.sin(up3angles)),axis=-1)
    if not noplot:
        f, ax = plt.subplots(1)
    else:
        f = None
        ax = None
    
    if plotaxes and not noplot:
        for i in range(6): # osy
            ax.plot(*np.transpose([-4*K3[i],4*K3[i]]),ls='-',c='k')
    iticks = np.arange(-32*n1,32*n1)[ň,:,ň]*K3[:,ň,:]  / K3len * s3/32 # [wi, site, x]
    scale_units = 'width'
    if magfield:
            triang = tri.Triangulation(maggrid[:,0], maggrid[:,1])
    
    gphase = np.array(gphase)
    animate = (gphase.ndim > 0)
    gphase = np.ravel(gphase)
    nphases = gphase.size
    origphases = phases    

    # zeroth index is global phase gpi
    phases = phases[ň,:] + gphase[:,ň] # [gpi, wi]
    iphases = np.sum(iticks * K3[:,ň,:], axis=-1 )-phases[:,:,ň] # [wi, site, /x/] * [wi, ň,/x/] - [gpi,wi, ň,] ~ [gpi,wi, site]
    phaseA = np.tensordot(K3, Asites, axes=(-1,-1))-phases[:,:,ň] # ([wi,/x/]*[site,/x/])-[gpi, wi, ň] ~ [gpi,wi,site]
    phaseB = np.tensordot(K3, Bsites, axes=(-1,-1))-phases[:,:,ň]
    iwaves = (np.exp(1j*iphases)[:,:, :, ň] * up3[:, ň, :] * facs[:, ň, ň]).real # exp[gpi,wi,site,ň]*[wi,ň,x]*[wi,ň,ň] ~ [gpi, wi,site,x]
    Awave = np.sum(np.exp(1j*phaseA)[:,:, :, ň] * up3[:, ň, :] * facs[:, ň, ň], axis=1).real # [gpi,/wi/,site,ň]*[/wi/,ň,x]*[/wi/,ň,ň] ~ [gpi,site,x]
    AwaveH = np.sum(np.exp(1j*phaseA)[:, :, :] * facs[:, ň], axis=1).imag
    Awave*=(abs(Awave)>1e-13)
    Bwave = np.sum(np.exp(1j*phaseB)[:,:, :, ň] * up3[:, ň, :] * facs[:, ň, ň], axis=1).real
    BwaveH = np.sum(np.exp(1j*phaseB)[:, :,:] * facs[:, ň], axis=1).imag
    Bwave*=(abs(Bwave)>1e-13)
    if magfield:
        magphases = np.tensordot(K3, maggrid, axes=(-1,-1)) - phases[:,:,ň] # [gpi,wi, magsite]
        magwaves = np.sum((np.exp(1j*magphases)[:,:,:] * facs[:,ň]).imag, axis=1)# [gpi, magsite]

    if pointmagfield:
        sites = np.concatenate((Asites, Bsites))
        waveH = np.concatenate((AwaveH, BwaveH), axis=1)
    
    if not noplot:
        gpi = 0
        if magfield:
            magcax = ax.tripcolor(triang, magwaves[gpi], cmap=magcmap, shading='gouraud')
            
        if plotplanewaves:
            pwax = ax.quiver(iticks[:,:,0], iticks[:,:,1],
                   iwaves[gpi,:,:,0],
                   iwaves[gpi,:,:,1],
                 lw=0.2, color= 'lime', headwidth=0, scale_units=scale_units, scale = wscale)

        #print (abs(waveH)*sscale)
        ax.scatter(Asites[:,0], Asites[:,1], marker='o', edgecolors=Asitecolor, facecolors='none',s=hsl**2/(2*xl)/(2*yl)*2500)
        ax.scatter(Bsites[:,0], Bsites[:,1], marker='o', edgecolors=Bsitecolor, facecolors='none',s=hsl**2/(2*xl)/(2*yl)*2500)
        if pointmagfield:
            pmfcax = ax.scatter(sites[:,0], sites[:,1], marker='o', s=abs(waveH[gpi])*sscale,
                   c=np.where(waveH[gpi]>0,'pink','lightblue') )
        Acax = ax.quiver(Asites[:,0],Asites[:,1],Awave[gpi,:,0],Awave[gpi,:,1], #headwidth=1, 
                         scale_units = scale_units, scale=ascale, pivot='mid',
                        color=Aarrowcolor)
        Bcax = ax.quiver(Bsites[:,0],Bsites[:,1],Bwave[gpi,:,0],Bwave[gpi,:,1], #headwidth=1, 
                         scale_units = scale_units, scale=ascale, pivot='mid',
                        color=Barrowcolor)
        if showcontribs:
                cAcax = ax.quiver(Asites[ň,:,0],Asites[ň,:,1],((np.exp(1j*phaseA)[gpi, :, :, ň] * up3[:, ň, :] * facs[:, ň, ň])[:,:,0]).real,
                                                  ((np.exp(1j*phaseA)[gpi, :, :, ň] * up3[:, ň, :] * facs[:, ň, ň])[:,:,1]).real,headwidth=1, scale_units = scale_units, scale=ascale, color='green' if (i < 3) else 'red')
                cBcax = ax.quiver(Bsites[ň,:,0],Bsites[ň,:,1],((np.exp(1j*phaseB)[gpi, :, :, ň] * up3[:, ň, :] * facs[:, ň, ň])[:,:,0]).real,
                                                  ((np.exp(1j*phaseB)[gpi, :, :, ň] * up3[:, ň, :] * facs[:, ň, ň])[:,:,1]).real,headwidth=1, scale_units = scale_units, scale=ascale, color='green' if (i < 3) else 'red')

        ax.set_xlim(-xl,xl)
        ax.set_ylim(-yl,yl)
        ax.set_aspect('equal')
        if showphase:
            ax.set_title('%.3f pi' % (gphase[gpi]/np.pi))
    if animate:
        def update_anim(frame):
            gpi = frame % nphases
            toreturn = list()
            if magfield:
                #nonlocal magcax
                #ax.remove(magcax)
                magcax.set_array(magwaves[gpi])
                toreturn.append(magcax)
            if pointmagfield:
                pmfcax.set_sizes(abs(waveH[gpi])*sscale)
                pmfcax.set_colors(np.where(waveH[gpi]>0,'pink','lightblue'))
                toreturn.append(pmfcax)
            pwax.set_UVC(iwaves[gpi,:,:,0], iwaves[gpi,:,:,1])
            Acax.set_UVC(Awave[gpi,:,0],Awave[gpi,:,1])
            Bcax.set_UVC(Bwave[gpi,:,0],Bwave[gpi,:,1])
            toreturn.extend([pwax,Acax,Bcax])
            if showcontribs:
                cAcax.set_UVC(((np.exp(1j*phaseA)[gpi, :, :, ň] * up3[:, ň, :] * facs[:, ň, ň])[:,:,0]).real,
                              ((np.exp(1j*phaseA)[gpi, :, :, ň] * up3[:, ň, :] * facs[:, ň, ň])[:,:,1]).real)
                cBcax.set_UVC(((np.exp(1j*phaseB)[gpi, :, :, ň] * up3[:, ň, :] * facs[:, ň, ň])[:,:,0]).real,
                              ((np.exp(1j*phaseB)[gpi, :, :, ň] * up3[:, ň, :] * facs[:, ň, ň])[:,:,1]).real)
                toreturn.extend([cAcax, cBcax])
            if showphase:
                ax.set_title('%.3f pi' % (gphase[gpi]/np.pi))
            toreturn.append(ax)
            return toreturn
        anim = matplotlib.animation.FuncAnimation(f, update_anim, interval=100, frames=nphases, blit=False)
        #HTML(anim.to_html5_video())
    else:
        anim = None
    return {'Awave':Awave,'Bwave':Bwave,'AwaveH':AwaveH, 'BwaveH':BwaveH,'Asites':Asites, 'Bsites':Bsites,'iticks': iticks,'iwaves': iwaves,
            'f': f, 'ax': ax, 'anim': anim}

bfacs = {
    'e1a': np.array((1,0,e**(2j*pt),0,e**(-2j*pt),0,))/s3,
    'e1b': np.array((0,1,0,e**(-2j*pt),0,e**(2j*pt),))/s3,
    'e2a': np.array((1,0,e**(-2j*pt),0,e**(2j*pt),0,))/s3,
    'e2b': np.array((0,1,0,e**(2j*pt),0,e**(-2j*pt),))/s3,
    'a2': np.array((1,1,1,1,1,1,))/s6,
    'a1': np.array((1,-1,1,-1,1,-1,))/s6,
}
ascales = {
    'e1a': 7,
    'e1b': 7,
    'e2a': 7,
    'e2b': 7,
    'a2': 2,
    'a1': 10,
}

# %%
res = dict()
for typ in ('a1', 'a2', 'e1a', 'e1b'):
    res[typ] = kpointplanewaves(gphase=pp, facs = bfacs[typ], transversal=True, magfield=False, wscale=10, 
                                ascale=ascales[typ], plotaxes = False, plotplanewaves=False, showphase=False)
    res[typ]['ax'].get_xaxis().set_ticks([])
    res[typ]['ax'].get_yaxis().set_ticks([])

# %%
res = dict()
for typ in ('a2',):
    res[typ] = kpointplanewaves(gphase=pp, facs = bfacs[typ], transversal=True, magfield=False, wscale=5, 
                                ascale=2, plotaxes = False, plotplanewaves=False, showphase=False)

# %%
# jenom K vlna (ne K')
typ = 'a1'

anim=kpointplanewaves(gphase=np.linspace(0,2*np.pi,15)
                 , facs=bfacs[typ], wscale=20, ascale=10, transversal=True)['anim']
#HTML(anim.to_html5_video())
#plt.draw()
#plt.show()
anim.save('/tmp/temp.mp4', fps=15, writer='avconv', codec='libx264')
with open('/tmp/temp.mp4', 'rb') as f:
    video_tag = '<video controls alt="test" src="data:video/x-m4v;base64,{0}">'.format(base64.b64encode(f.read()).decode('utf-8'))
HTML(video_tag)
#anim.save('/tmp/test.gif', writer='imagemagick')
# Out:
# <video controls alt="test" src="data:video/x-m4v;base64,...">

# %%
for typ in ['a1',]: #bfacs.keys():
  for transversal in [True, False]:
    anim=kpointplanewaves(gphase=np.linspace(0,2*np.pi,150)
                 , facs=bfacs[typ], wscale=20, ascale=20, transversal=transversal)['anim']
    anim.save('/home/mmn/hexx/K3_%s_%s.mp4' % ('trans' if transversal else 'long', typ), fps=15, writer='avconv', codec='libx264')

# %%
# Fig 11.11 (b)
kpointplanewaves(gphase=pt,
                               facs=bfacs['e1b'], transversal=True, );

# %%
kpointplanewaves(gphase=-0.2,
                facs=bfacs['a2'], wscale=20 ,
                      rot=False, transversal=True);

# %%
# Fig 11.11 (a)
kpointplanewaves(gphase=pp,
                 #facs=(.5,-1,.5,.5,-1,.5,), 
                 facs=bfacs['a2'],
                 wscale=15,rot=False, transversal=True);

# %%
gphase = np.linspace(0,2*np.pi,80)
for index, delay in enumerate(gphase):
    _,_,_,_,_,_,_,_, f, _ = kpointplanewaves(gphase=delay, facs=bfacs['e1a'], transversal=True, rot=False)
    plt.savefig('/tmp/transversal_e1a_frame%03i.png'%index)
    plt.close(f)

# %%
gphase = np.linspace(0,2*np.pi,80)
for index, delay in enumerate(gphase):
    _,_,_,_,_,_,_,_, f, _ = kpointplanewaves(gphase=delay, facs=bfacs['e1b'], transversal=True, rot=False)
    plt.savefig('/tmp/transversal_e1b_frame%03i.png'%index)
    plt.close(f)

# %%
gphase = np.linspace(0,2*np.pi,80)
for index, delay in enumerate(gphase):
    _,_,_,_,_,_,_,_, f, _ = kpointplanewaves(gphase=delay, facs=bfacs['a1'], transversal=True, rot=False)
    plt.savefig('/tmp/transversal_a1_frame%03i.png'%index)
    plt.close(f)

# %%
gphase = np.linspace(0,2*np.pi,80)
for index, delay in enumerate(gphase):
    _,_,_,_,_,_,_,_, f, _ = kpointplanewaves(gphase=delay, facs=bfacs['a2'], transversal=True, rot=False)
    plt.savefig('/tmp/transversal_a2_frame%03i.png'%index)
    plt.close(f)

# %%
gphase = np.linspace(0,2*np.pi,80)
for index, delay in enumerate(gphase):
    _,_,_,_,_,_,_,_, f, _ = kpointplanewaves(gphase=delay, facs=bfacs['e2a'], transversal=True, rot=False)
    plt.savefig('/tmp/transversal_e2a_frame%03i.png'%index)
    plt.close(f)

# %%
gphase = np.linspace(0,2*np.pi,80)
for index, delay in enumerate(gphase):
    _,_,_,_,_,_,_,_, f, _ = kpointplanewaves(gphase=delay, facs=bfacs['e2b'], transversal=True, rot=False)
    plt.savefig('/tmp/transversal_e2b_frame%03i.png'%index)
    plt.close(f)

# %%
gphase = np.linspace(0,2*np.pi,80)
for irrep in bfacs.keys():
 for index, delay in enumerate(gphase):
    _,_,_,_,_,_,_,_, f, _ = kpointplanewaves(gphase=delay, facs=bfacs[irrep], transversal=False, magfield=False, rot=False)
    plt.savefig('/tmp/longitudinal_%s_frame%03i.png'%(irrep,index))
    plt.close(f)

# %%
bpath='/m/home/home4/46/necadam1/unix/hexx/projs/'
gphase = np.linspace(0,2*np.pi,40,endpoint=False)
for rot in (True,False):
    for polang in (-60,-45,-30,0,30,45,60,90):
        os.makedirs('%s%s%d/src' % (bpath,'rot/' if rot else 'base/',polang), exist_ok=True)
        pa = polang * np.pi / 180
        for index, delay in enumerate(gphase):
            for typ in 'c':#('a','d','b','adl','adr'):
                f, ax = kpointplanewaves_proj(gphase=delay,
                            phases=bphases[typ],
                            facs=bfacs[typ], wscale=20, proj=(math.cos(pa),math.sin(pa)) ,rot=rot);
                plt.savefig('%s%s%d/src/%s_%03i.png'%(bpath,'rot/' if rot else 'base/',polang,typ,index))
                plt.close(f)

# %%
for typ in ('a','b','d'):
    ft,f,ax=kptf(gphase=pp,
                phases=bphases[typ],
                facs=bfacs[typ], wscale=20 ,
                      rot=False)
    plt.savefig('/tmp/ft_%s.pdf'%typ)
    plt.close(f)

# %% [markdown]
# for i in ${t}_frame*.png ; do  convert $i $(basename $i .png).gif ; done ; convert -delay 10 -loop 0 ${t}_frame*.gif ${t}.gif ; rm ${t}_frame*.*
#
# for angle in */* ; do
#   cd $angle
#   for t in c; do # a d b adl adr; do
#     for i in src/${t}_*.png; do
#       convert $i $(basename $i .png).gif
#     done
#     convert -delay 10 -loop 0 ${t}_*.gif ${t}.gif
#     rm ${t}_*.gif
#   done
#   cd -
# done
